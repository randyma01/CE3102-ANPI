// %% [markdown]
// <h1 style="text-align: center; color: #000000;">
//     <strong>Método Iterativo de Solución de Ecuaciones: Jacobi</strong>
// </h1>

// %% [markdown]
// <span style="font-size: 12.0pt">
//     <ul>
//         <li style="margin: 2rem">
//             <strong>Curso:</strong>
//             [CE-3102] - Análisis Numéricos para Ingeniería
//         </li>
//         <li style="margin: 2rem">
//             <strong>Estudiante: </strong>
//             [2014047395] - Randy Alejandro Martínez Sandí
//         </li>
//         <li style="margin: 2rem">
//             <strong>Evaluación: </strong>
//             Catálago Grupal
//         </li>
//         <li style="margin: 2rem">
//             <strong>Fecha: </strong>
//             6 de noviembre, 2020
//         </li>
//     </ul>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; color: #000000">
//     <h2 style="text-align: center;">
//         <span>
//             <strong>Contenidos</strong>
//         </span>
//     </h2>
//
// [<strong>1. Análisis Matemático</strong>](#ac)
//
// [<strong>2. Características</strong>](#ca)
//
// [<strong>3. Diagrama de Flujo</strong>](#df)
//
// [<strong>4. Código: C++ (v17)</strong>](#cp)
//
// [<strong>5. Ejemplo Numérico</strong>](#em)
//
// [<strong>6. Referencias Bibliográficas</strong>](#rf)
//
// </span>

// %% [markdown]
// <span style="color: #676767">
// <a id='ac'></a>
// <h2>
//     <span>
//         <span style="text-decoration: underline;">
//             <strong>1. Análisis Matemático</strong>
//         </span>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="color: #838383">
// <a id="mat"></a>
// <h2>
//     <span>
//         <strong>1.1 Matrices</strong>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// Todo sistema de ecuaciones, por ejemplo;
//
// $$
// \left.
// 2x_1 + x_2  = 1 \atop
// x_1 + x_2 = 4
// \right\}
// $$
//
// tiene una representación matricial de la forma:
//
// $$
// \begin{equation*}
// \begin{pmatrix}
// 2 & 1 \\
// 1 & 1 \\
// \end{pmatrix}
// \times
// \begin{pmatrix}
// x_1 \\
// x_2
// \end{pmatrix}
// =
// \begin{pmatrix}
// 1 \\
// 4
// \end{pmatrix}
// \end{equation*}
// $$
//
// Donde:
//
//   - La primera matriz (llamada matriz de coeficientes) representa los coeficientes de la ecuación.
//     Esta se representa con la letra:
//     **A**
//
//
//
//   - La segunda matriz (llamada matriz de incógnitas) representa los valores a determinar.
//      Esta se representa con la letra:
//     **x**
//
//
//
//   - La tercera matriz (llamada matriz de términos independientes) representa la igualdad de cada ecuación.
//      Esta se representa con la letra:
//     **b**
//
// De las matrices anteriores, se puede obtener la ecuación:
//
// $$
// \begin{equation*}
// Ax = b
// \end{equation*}
// $$
//
// Esto es, para toda matriz de tamaño MxM, es decir: misma cantidad de columnas y filas. Asimismo, la cantidad de filas para la matriz de términos independientes.
//
// En otras palabras, el número de ecuaciones independientes y el número de incógnitas deben ser las mismas.
//
// </span>

// %% [markdown]
// <span style="color: #838383">
// <a id="jac"></a>
// <h2>
//     <span>
//         <strong>1.2 Solución de Matrices: Jacobi</strong>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// Hay múltiples formas de resolver la ecuación anterior. Un enfoque es utilizar iteraciones para aproximar la solución. Conmunmente, se utilizan sumas sucesivas. Los métodos iterativos tienen a seguir el siguiente esquema:
//
// La matriz A se puede descomponener así:
//
// $$
// \begin{equation*}
// A = L + D + U
// \end{equation*}
// $$
//
// donde:
//
//   -  **L** es la matriz de A, pero únicamente con los valores debajo de la diagonal
//
//
//   -  **D** es la matriz de A, pero únicamente con los valores de la diagonal
//
//
//   -  **U** es la matriz de A, pero únicamente con los valores arriba de la diagonal
//
// El método de Jacobi se basa en la siguiente expresión:
//
// $$
// \begin{equation*}
// A = M - N
// \end{equation*}
// $$
//
// donde,
//
// $$
// \begin{equation*}
// M = D  \\
// N = -(L + U)
// \end{equation*}
// $$
//
//
// Ahora, partiendo de la ecuación:
//
// $$
// \begin{equation*}
// Ax = b
// \end{equation*}
// $$
//
// sustityendo **M** y **N** en **A** se obtiene la igualdad de:
//
// $$
// \begin{equation*}
// (M + N)x = b \\
// Mx + Nx = b
// \end{equation*}
// $$
//
// En este punto, se desea dejar una variable **x** en cada lado del igual. Por lo que se va a despejar el **M** de la siguiente manera:
//
// $$
// \begin{equation*}
// Mx = b - Nx
// \end{equation*}
// $$
//
// Y ahora, se despeja **x**, obteniendo la ecuación final de:
//
// $$
// \begin{equation*}
// x = M^{-1}(b - Nx)
// \end{equation*}
// $$
//
// Al ser una iteración, la fórmula final, (*), seria:
//
//
// $$
// \left.
// x^{(k+1)} = M^{-1}(b - Nx^{(k)}) \atop
// x^{0} \in R^{n}
// \right\}
// $$
//
//
// Donde, el vector
//
// $$
// x^{0} \in R^{n}
// $$
//
// corresponde a vector inicial, está compuesto de ceros y es de tamaño de la cantidad de incógnitas del sistema de ecuaciones.
//
// Además,
//
// $$
// x^{k}
// $$
//
// representa el valor anterior calculado, iniciando con el vector inicial y,
//
// $$
// x^{k+1}_j
// $$
//
// representa el último, k-ésimo, valor calculado.
//
//
// La fórmula (*), al ser una iteración, se puede moldear como una serie, la cual se puede representar de la siguiente forma:
//
// $$
// \begin{equation*}
// x^{(k+1)} = \dfrac{1}{a_{ii}} (b_i - \sum_{i=1}^{k} n_{ij}x_j^{k}) \\
// i = 1, 2, 3, ...
// \end{equation*}
// $$
//
// Donde:
//
// - **M** es la matriz de diagonales de la matriz **A** y se representa como:
//
// $$
// \dfrac{1}{a_{ii}}
// $$
//
//
// - **b** es el vector de términos independientes y se representa como:
//
// $$
// b_{i}
// $$
//
// - **N** es la matriz sin diagonales de la **A** como:
//
// $$
// n_{ij}
// $$
//
// - **x** es el vector resultante de la suma anterior. Este inicial con el vector de valores de cero, y se representa como:
//
// $$
// x^{k}_{j}
// $$
//
//
// Esta es la forma no matricial de representación de la solución del sistema ecuaciones. Esta misma forma que se utiliza en la implementación computacional del método, que se muestran más adelante en la secciones [4. Código: C++ (v17)](#cp)
//
// </span>

// %% [markdown]
// <span style="color: #676767">
// <a id='ca'></a>
// <h2>
//     <span>
//         <span style="text-decoration: underline;">
//             <strong>2. Características</strong>
//         </span>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="color: #838383">
// <a id="con"></a>
// <h2>
//     <span>
//         <strong>2.1 Convergencia</strong>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// El método de Jacobi tiene una convergencia hacia las matrices diagonalmente dominantes.
//
// Una matriz diagonalmente dominante es aquella donde el valor absoluto del elemento de la diagonal es mayor a la suma de lso valores absolutos de los demás elementos de una fila dada.
//
// Si se aplica el método de Jacobi a una matriz con esta característica, siempre se va a obtner un cálculo aproximado de la solcuión al sistema.
//
// En caso de que la matriz no sea diagonalmente dominante, puede que converga a la solución así como pueda que diverga.
//
// Es por eso que al convergencia tiende a estas matrices.
//
// </span>

// %% [markdown]
// <span style="color: #838383">
// <a id="cri"></a>
// <h2>
//     <span>
//         <strong>2.2 Criterio de Parada</strong>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// El métood de Jacobi al ser un método iteravo, va a repetirse una cantidad "n" de veces, hasta llegar a su criterio de parada, el cual es:
//
// $$
// error absoluto < tolerancia
// $$
//
// donde la **tolerancia**, que es dada, debe ser mayor al **error absoluto**, donde este es la norma de la expresión:
//
// $$
// Ax^{k} - b
// $$
//
// Por lo tanto, de manera formal, el criterio de parada es:
//
// $$
// ||Ax^{(k)} - b|| < tol
// $$
//
// La norma a aplicar para el cálculo del valor absoluto queda a decisión subjetiva. Se recomienda utilizar la norma 2, también llamada norma Euclidiana.
//
// </span>

// %% [markdown]
// <span style="color: #838383">
// <a id="dvs"></a>
// <h2>
//     <span>
//         <strong>2.3 Ventajas y desventajas</strong>
//     </span>
// </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// **Ventajas**:
//
// - Realiza pocas operaciones matriciales.
//
//
// - El margen de error puede llegar a ser muy pequeño.
//
//
// - De no requerir mucha presición, pueden hacer pocas iteraciones, reduciendo el proceso.
//
//
// **Desventajas**:
// - Al ser un metodo iterativo puede consumir muchosos recursos, convirtiéndolo computacionalmente pesado.
//
//
// - Su convergencia es estricta, debido a que en muchos casos diverge.
//
//
// - El tiempo de cálculo y la precisión del resultado pueden depender de la elección de ciertos parámetros       como: la tolerancia.
//
// </span>

// %% [markdown]
// <span style="color: #676767">
//     <a id='df'></a>
//     <h2>
//         <span>
//             <span style="text-decoration: underline;">
//                 <strong>3. Diagrama de Flujo</strong>
//             </span>
//         </span>
//     </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// Acontinuación se muestra el diagrama de flujo del método de Jacobi.
//
// Este tiene el enfoque según las condiciones explicadas en el 1. Análisis Matemético y dirigido hacia la implementación de código que se muestran en las secciones [4. Código: C++ (v17)](#cp)
//
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt">
//     <div>
//         <img src="attachment:diagrama_flujo_jacobi.png" width="500"/>
//     </div>
//
// </span>

// %% [markdown]
// <span style="color: #676767">
//     <a id='cp'></a>
//     <h2>
//         <span>
//             <span style="text-decoration: underline;">
//                 <strong>4. Código: C++ (v17)</strong>
//             </span>
//         </span>
//     </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// Acontinuación se muestra código de la implementación del método de Jacobi para el lenguaje de programación en C++ en la versión 17.
//
// ```Aclaración: Para este trabajo, se basó en los códigos encontrados en las referencias [1] y [2]. Se tomó como guías esas implementaciones investigadas y se les hicieron los ajustos pertinentes para esta evaluación. Todos los derechos a sus respectivos autores.```
//
// Este consiste en dos funciones:
//
// - **Jacobi**: Verifica que dada una matriz, esta sea diagnomalmente dominante, hace la invoación a la función JacobiAux.
//
//
// - **JacobiAux**: Realiza el cálculo de la solución de un sistema de ecuaciones.
//
//
// Para demostración su funcionamiento, se va a calcular la solución del siguiente sistema de ecuaciones:
//
// $$
// \begin{equation*}
// \begin{pmatrix}
// 5 & 1 & 1 \\
// 1 & 5 & 1 \\
// 1 & 1 & 5 \\
// \end{pmatrix}
// \times
// \begin{pmatrix}
// x_1 \\
// x_2 \\
// x_3 \\
// \end{pmatrix}
// =
// \begin{pmatrix}
// 7 \\
// 7 \\
// 7
// \end{pmatrix}
// \end{equation*}
// $$
//
// donde su solución es la matriz columna:
//
// $$
// \begin{equation*}
// \begin{pmatrix}
// x_1 \\
// x_2 \\
// x_3 \\
// \end{pmatrix}
// =
// \begin{pmatrix}
// -1 \\
// -1 \\
// -1 \\
// \end{pmatrix}
// \end{equation*}
// $$
//
// </span>

// %%
#include<iostream>

#include<stdlib.h>

#define n 10

// %%
using namespace std;

// %%
float norma(float vector1[],float vector2[], int l){
    float aux = 0;
    int i;
    for(i = 0; i < l; i++){
        aux = aux + (vector1[i] - vector2[i]) * (vector1[i] - vector2[i]);
    }
    return aux;
}

// %%
/**
* Esta funcion encuentra la solucion a un sistema 
* de ecuaciones representado mediante la expresion:
* A * x = b, utilizando el metodo de Jacobi.
*
* El metodo de Jacobi utiliza la siguiente formula:
* -> A * x = b   
* -> (M - N) * x = b
* -> M * x = (N * x) + b
* -> x = (M^-1 * N * x) + (M^-1 * b)
*
* donde:
*
* -> M^-1 = matriz diagonal inversa
* -> N = matriz A con diagonal de ceros y valores negativos
*
* Firma: 
*   jacobi(l, A, b)
* 
* Entradas:
*   l = cantidad de incognitas
*   A = matriz de coeficientes
*   b = vector de valores independientes
*            
* Salida:                           
*   xk = vector de incognitas
*/
void JacobiAux(int l, float x[], float a[][10], float b[]){
    // declaracion: vector resultantes
    float c[n];
    
    // declaracion: contador de iteraciones
    int k;
    
    // declaracion: de cantidad de filas
    int i;
    
    // declaracion: de cantidad de columnas
    int j;
    
    // declaracion: tolerancia
    float tol = 0.000000010;
    
    // declaracion: error
    float error = tol + 1;
    
    // iteracion: dada 30 iteraciones hace el calculo de //
    // del vector resultante //
    for(k = 0; k < 30; k++){
        
        for(i = 0;i < l; i++) {
            c[i] = b[i];
            for(j = 0; j < l;j++) {
                if(i != j) {
                    c[i] = c[i] - a[i][j] * x[j];
                }
            }
        }
        
        for(i = 0; i < n; i++) {
            x[i] = c[i] / a[i][i];
        }
    }
    
    cout<<"La solucion es: "<<endl;
    for(i = 0; i < l; i++) {
        cout<<"x("<< i <<") = "<< x[i]<< endl;
    }
    cout<<"Iteraciones= "<< k << endl;
}

// %%
/**
*
* Esta funcion encuentra la solucion a un sistema 
* de ecuaciones representado mediante la expresion:
* A * x = b, utilizando el metodo de Jacobi.
*
* El metodo de Jacobi utiliza la siguiente formula:
* -> A * x = b   
* -> (M - N) * x = b
* -> M * x = (N * x) + b
* -> x = (M^-1 * N * x) + (M^-1 * b)
*
* donde:
*
* -> M^-1 = matriz diagonal inversa
* -> N = matriz A con diagonal de ceros y valores negativos
*
* Firma: 
*   jacobi(l, A, b)
* 
* Entradas:
*   l = cantidad de incognitas
*   A = matriz de coeficientes
*   b = vector de valores independientes
*            
* Salida:                           
*   xk = vector de incognitas
* 
* Nota: El algoritmo realiza 30 iteraciones. 
*/
void Jacobi(int l, float a[][10], float b[]){
    // declaracion: dimension de las filas
    int i;

    // declaracion: dimension de columnas //
    int j;

    // declaracion: contador general //
    int cont = 0;

    // declaracion: vector de las incognitas //
    float x[n];

    // declaracion: valor diagonal dominante //
    float dd = 0.0;

    // declaracion: resultado de las sumas de als filas //
    float suma;

    // verificacion: la matriz debe ser diagonalmente dominante //
    for(i = 0; i < l; i++){
        suma = 0;
        for(j = 0; j < l; j++){
            if(i == j){
                dd = a[i][j];
            }else{
                suma += a[i][j];
            }
        }
        if(suma < dd){
            cont++;
        }
    }
    
    // condicion: si es diagnonalmente dominante se ejecuta el metodo de jacobi
    if(cont == l){
        JacobiAux(l, x, a, b);
    }else{
        cout<<"La matriz no es diagonalmente dominante."<<endl;
    }
}

// %%
float a[n][n] = {
         {5, 1, 1},
         {1, 5, 1},
         {1, 1, 5}
};

float b[n] = {7, 7, 7};

int l = 3;

Jacobi(l, a, b)
// Out:
// La solucion es:
// x(0) = 1
// x(1) = 1
// x(2) = 1
// Iteraciones= 30

// %% [markdown]
// <span style="color: #676767">
//     <a id='em'></a>
//     <h2>
//         <span>
//             <span style="text-decoration: underline;">
//                 <strong>6. Ejemplo Numérico</strong>
//             </span>
//         </span>
//     </h2>
// </span>

// %% [markdown]
// <span style="font-size: 12.0pt; line-height: 150%">
//
// A continuación se muestra un ejemplo número aplicado a la ingeniería. Este mismo ejemplo fue tomado del libro
//     **Métodos Númericos para Ingenieros**
// (5ta Ed, 2012) escrito por Steven C. Chapra y Raymond P. Canale.
//
// Este se basó en los ejericios 10.8 y 11.8, tomado de las páginas 303 y 325, respectivamente. [[3]](#lr).
//
//  El cual dice:
//
// _El sistema de ecuaciones que sigue está diseñado para determinar concentraciones (las c están en g/m3) en una serie de reactores acoplados, como función de la cantidad de masa que entra a cada uno de ellos (los lados derechos están en g/día)_
//
// $$
// \begin{equation*}
// 15c_1 – 3c_2 – c_3 = 3800 \\
// –3c_1 + 18c_2 – 6c_3 = 1200 \\
// –4c_1 – c_2 + 12c_3 = 2350 \\
// \end{equation*}
// $$
//
//
// _Del problema 10.8, recuerde que el sistema de ecuaciones siguiente está diseñado para determinar concentraciones (las c están en g/m3) en una serie de reactores acoplados como función de la cantidad de masa de entrada a cada uno de ellos (los lados derechos están en g/d)._
//
// Si se resuelve el sistema de ecuaciones para encontrar el la cantidad de concentraciones por día según las condiciones dadas anteriormente, se obtiene el los siguientes resultados:
//
//   $$
// \begin{equation*}
// \begin{pmatrix}
// c_1 \\
// c_2 \\
// c_3 \\
// \end{pmatrix}
// =
// \begin{pmatrix}
// 320.21 \\
// 227.20 \\
// 321.50 \\
// \end{pmatrix}
// \end{equation*}
// $$
//
// Al ingresar el sistema de ecuaciones en las funciones previamente programdas (GNU Octave y Python), se obtienen los siguientes resultados, respectivamente:
//
// </span>

// %%
float a[n][n] = {
         {15, -3, -1},
         {-3, 18, -6},
         {-4, -1, 12}
};

float b[n] = {3800, 1200, 2350};

int l = 3;

Jacobi(l, a, b)
// Out:
// La solucion es:
// x(0) = 320.207
// x(1) = 227.202
// x(2) = 321.503
// Iteraciones= 30

// %% [markdown]
// <span style="color: #676767">
//     <a id='rf'></a>
//     <h2>
//         <span>
//             <span style="text-decoration: underline;">
//                 <strong>7. Referencias Bibliográficas </strong>
//             </span>
//         </span>
//     </h2>
// </span>

// %% [markdown]
// <span id='lr' style="font-size: 12.0pt; line-height: 150%">
//
//
// [1] Anónimo. (2017). _Método de Jacobi_. [Blog] Tomado de: https://cypascal.blogspot.com/2016/06/metodo-de-jacobi-programado-en-cc.html
//
//
// [2] Anónimo. (2017). _Método de Jacobi de resolución de sistemas programado en C/C++_. [Blog] Tomado de: https://cypascal.blogspot.com/2016/06/metodo-de-jacobi-programado-en-cc.html
//
//
// [3] Chapra, S. C. & Canale R. P. (2007). _Numerical methods for engineers (5da. ed.)._ New York: McGraw-Hill.
//
//
// [4] Soto, J. P. (2020). _Presentación 5: Solución de Sistemas de Ecuaciones Métodos Iterativos CE-3102: Análisis Numéricos para Ingeniería._. Área Académica de Ingenría en Computadores. Instituto Tecnológico de Costa Rica. Costa Rica.
//
//
// [5] Unioviedo. (sf). _Sistemas de ecuaciones lineales_.  Escuela de Ingenería de Oviedo Informática de Oviedo. Universidad de Oviedo. España [PDF] TOmado de: https://www.unioviedo.es/compnum/expositiva/Presentaciones_web/T5_sist_lineales.pdf
//
// </span>
