% %%
2+3
% Out:
% ans =  5

% %%
plot(1:5)

% %%
pkg load symbolic
syms x
f=x^3-cos(x)+1;
g=diff(f)
% Out:
% Symbolic pkg v2.9.0: Python communication link active, SymPy v1.5.1.
% g = (sym)
%
%      2
%   3⋅x  + sin(x)
